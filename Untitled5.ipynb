# %%
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
cd C:/Users/Radha
# Out:
# C:\Users\Radha

# %%
df1= pd.read_csv("C:\Users\Radha\Desktop\LogReg_DT\ex2data1.csv)
# Out:
#   File "<ipython-input-4-608336639c87>", line 1
#     df1= pd.read_csv("C:\Users\Radha\Desktop\LogReg_DT\ex2data1.csv)
#                                                                    ^
# SyntaxError: EOL while scanning string literal

# %%
data = pd.read_csv("C:\Users\Radha\Desktop\LogReg_DT\ex2data1.csv", header=None, names=['Exam 1', 'Exam 2', 'Admitted'])  
data.head()
# Out:
#         Exam 1       Exam 2  Admitted
# 0        Exam1        Exam2  Accepted
# 1  34.62365962  78.02469282         0
# 2  30.28671077  43.89499752         0
# 3  35.84740877  72.90219803         0
# 4  60.18259939   86.3085521         1

# %%
positive = data[data['Admitted'].isin([1])]  
negative = data[data['Admitted'].isin([0])]

# %%
positive = data[data['Admitted'].isin([1])]  
negative = data[data['Admitted'].isin([0])]
fig, ax = plt.subplots(figsize=(12,8))  
ax.scatter(positive['Exam 1'], positive['Exam 2'], s=50, c='b', marker='o', label='Admitted')  
ax.scatter(negative['Exam 1'], negative['Exam 2'], s=50, c='r', marker='x', label='Not Admitted')  
ax.legend()  
ax.set_xlabel('Exam 1 Score')  
ax.set_ylabel('Exam 2 Score')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-4df7c80e255d> in <module>()
#       2 negative = data[data['Admitted'].isin([0])]
#       3 fig, ax = plt.subplots(figsize=(12,8))
# ----> 4 ax.scatter(positive['Exam 1'], positive['Exam 2'], s=50, c='b', marker='o', label='Admitted')
#       5 ax.scatter(negative['Exam 1'], negative['Exam 2'], s=50, c='r', marker='x', label='Not Admitted')
#       6 ax.legend()
#
# C:\Users\Radha\Anaconda2\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1816                     warnings.warn(msg % (label_namer, func.__name__),
#    1817                                   RuntimeWarning, stacklevel=2)
# -> 1818             return func(ax, *args, **kwargs)
#    1819         pre_doc = inner.__doc__
#    1820         if pre_doc is None:
#
# C:\Users\Radha\Anaconda2\lib\site-packages\matplotlib\axes\_axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3836
#    3837         # c will be unchanged unless it is the same length as x:
# -> 3838         x, y, s, c = cbook.delete_masked_points(x, y, s, c)
#    3839
#    3840         scales = s   # Renamed for readability below.
#
# C:\Users\Radha\Anaconda2\lib\site-packages\matplotlib\cbook.pyc in delete_masked_points(*args)
#    1846         return ()
#    1847     if (is_string_like(args[0]) or not iterable(args[0])):
# -> 1848         raise ValueError("First argument must be a sequence")
#    1849     nrecs = len(args[0])
#    1850     margs = []
#
# ValueError: First argument must be a sequence

# %%
positive = data[data['Admitted'].isin([1])]  
negative = data[data['Admitted'].isin([0])]
fig, ax = plt.subplots(figsize=(12,8))  
ax.scatter(positive['Exam 1'], positive['Exam 2'], s=50, c='b', marker='o', label='Admitted')  
ax.scatter(negative['Exam 1'], negative['Exam 2'], s=50, c='r', marker='x', label='Not Admitted')  
ax.legend()  
ax.set_xlabel('Exam 1 Score')  
ax.set_ylabel('Exam 2 Score')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-4df7c80e255d> in <module>()
#       2 negative = data[data['Admitted'].isin([0])]
#       3 fig, ax = plt.subplots(figsize=(12,8))
# ----> 4 ax.scatter(positive['Exam 1'], positive['Exam 2'], s=50, c='b', marker='o', label='Admitted')
#       5 ax.scatter(negative['Exam 1'], negative['Exam 2'], s=50, c='r', marker='x', label='Not Admitted')
#       6 ax.legend()
#
# C:\Users\Radha\Anaconda2\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1816                     warnings.warn(msg % (label_namer, func.__name__),
#    1817                                   RuntimeWarning, stacklevel=2)
# -> 1818             return func(ax, *args, **kwargs)
#    1819         pre_doc = inner.__doc__
#    1820         if pre_doc is None:
#
# C:\Users\Radha\Anaconda2\lib\site-packages\matplotlib\axes\_axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3836
#    3837         # c will be unchanged unless it is the same length as x:
# -> 3838         x, y, s, c = cbook.delete_masked_points(x, y, s, c)
#    3839
#    3840         scales = s   # Renamed for readability below.
#
# C:\Users\Radha\Anaconda2\lib\site-packages\matplotlib\cbook.pyc in delete_masked_points(*args)
#    1846         return ()
#    1847     if (is_string_like(args[0]) or not iterable(args[0])):
# -> 1848         raise ValueError("First argument must be a sequence")
#    1849     nrecs = len(args[0])
#    1850     margs = []
#
# ValueError: First argument must be a sequence

# %%
plt.plot(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-03b19d2bdac0> in <module>()
# ----> 1 plt.plot(data)
#
# C:\Users\Radha\Anaconda2\lib\site-packages\matplotlib\pyplot.pyc in plot(*args, **kwargs)
#    3159         ax.hold(hold)
#    3160     try:
# -> 3161         ret = ax.plot(*args, **kwargs)
#    3162     finally:
#    3163         ax.hold(washold)
#
# C:\Users\Radha\Anaconda2\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1816                     warnings.warn(msg % (label_namer, func.__name__),
#    1817                                   RuntimeWarning, stacklevel=2)
# -> 1818             return func(ax, *args, **kwargs)
#    1819         pre_doc = inner.__doc__
#    1820         if pre_doc is None:
#
# C:\Users\Radha\Anaconda2\lib\site-packages\matplotlib\axes\_axes.pyc in plot(self, *args, **kwargs)
#    1381
#    1382         for line in self._get_lines(*args, **kwargs):
# -> 1383             self.add_line(line)
#    1384             lines.append(line)
#    1385
#
# C:\Users\Radha\Anaconda2\lib\site-packages\matplotlib\axes\_base.pyc in add_line(self, line)
#    1701             line.set_clip_path(self.patch)
#    1702
# -> 1703         self._update_line_limits(line)
#    1704         if not line.get_label():
#    1705             line.set_label('_line%d' % len(self.lines))
#
# C:\Users\Radha\Anaconda2\lib\site-packages\matplotlib\axes\_base.pyc in _update_line_limits(self, line)
#    1723         Figures out the data limit of the given line, updating self.dataLim.
#    1724         """
# -> 1725         path = line.get_path()
#    1726         if path.vertices.size == 0:
#    1727             return
#
# C:\Users\Radha\Anaconda2\lib\site-packages\matplotlib\lines.pyc in get_path(self)
#     936         """
#     937         if self._invalidy or self._invalidx:
# --> 938             self.recache()
#     939         return self._path
#     940
#
# C:\Users\Radha\Anaconda2\lib\site-packages\matplotlib\lines.pyc in recache(self, always)
#     632                 y = ma.asarray(yconv, np.float_).filled(np.nan)
#     633             else:
# --> 634                 y = np.asarray(yconv, np.float_)
#     635             y = y.ravel()
#     636         else:
#
# C:\Users\Radha\Anaconda2\lib\site-packages\numpy\core\numeric.pyc in asarray(a, dtype, order)
#     480
#     481     """
# --> 482     return array(a, dtype, copy=False, order=order)
#     483
#     484 def asanyarray(a, dtype=None, order=None):
#
# ValueError: could not convert string to float: Exam1
